# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork865-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>
#
# <h1 align=center><font size = 5>Assignment: SQL Notebook for Peer Assignment</font></h1>
#
# Estimated time needed: **60** minutes.
#
# ## Introduction
# Using this Python notebook you will:
#
# 1.  Understand the Spacex DataSet
# 2.  Load the dataset  into the corresponding table in a Db2 database
# 3.  Execute SQL queries to answer assignment questions

# %% [markdown]
# ## Overview of the DataSet
#
# SpaceX has gained worldwide attention for a series of historic milestones.
#
# It is the only private company ever to return a spacecraft from low-earth orbit, which it first accomplished in December 2010.
# SpaceX advertises Falcon 9 rocket launches on its website with a cost of 62 million dollars wheras other providers cost upward of 165 million dollars each, much of the savings is because Space X can reuse the first stage.
#
#
# Therefore if we can determine if the first stage will land, we can determine the cost of a launch.
#
# This information can be used if an alternate company wants to bid against SpaceX for a rocket launch.
#
# This dataset includes a record for each payload carried during a SpaceX mission into outer space.

# %% [markdown]
# ### Download the datasets
#
# This assignment requires you to load the spacex dataset.
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. Click on the link below to download and save the dataset (.CSV file):
#
#  <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv" target="_blank">Spacex DataSet</a>

# %% [markdown]
# **Navigate to the Go to UI screen**
#
# * Refer to this insruction in this <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Sign%20up%20for%20IBM%20Cloud%20-%20Create%20Db2%20service%20instance%20-%20Get%20started%20with%20the%20Db2%20console/instructional-labs.md.html">link</a> for viewing  the   Go to UI screen.
#
#
# * Later click on **Data link(below SQL)**  in the Go to UI screen  and click on **Load Data** tab.
#
#
#
# * Later browse for the downloaded spacex file.
#
#
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/images/browsefile.png" width="800">
#
#
# * Once done select the schema andload the file.
#
#
#  <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/images/spacexload3.png" width="800">

# %% [markdown]
# If you are facing a problem in uploading the dataset (which is a csv file), you can follow the steps below to upload the .sql file instead of the CSV file:
#
# * Download the file <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/Spacex%20.sql">Spacex.sql</a>
#
# * Later click on **SQL** in the  **Go to UI Screen**.
#
# * Use the **From file** option to browse for the **SQL** file and upload it.
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/images/sqlfile.png">
#
# * Once you upload the script,you can use the **Run All** option to run all the queries to insert the data.
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/images/runall.png">

# %%
# !pip install --force-reinstall ibm_db==3.1.0 ibm_db_sa==0.3.3
# !pip install sqlalchemy==1.3.24
# !pip uninstall ipython-sql -y
# !pip install ipython-sql==0.4.1
# Out:
# Processing c:\users\kiit\appdata\local\pip\cache\wheels\43\71\0a\3065745bc1dc4cafbdcb09e2557082609f7689b16108b670df\ibm_db-3.1.0-py3-none-any.whl
# Collecting ibm_db_sa==0.3.3
#   Using cached ibm_db_sa-0.3.3.tar.gz (24 kB)
# Collecting sqlalchemy>=0.7.3
#   Downloading SQLAlchemy-2.0.19-cp38-cp38-win_amd64.whl (2.0 MB)
# Collecting typing-extensions>=4.2.0
#   Using cached typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Collecting greenlet!=0.4.17; platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32")))))
#   Using cached greenlet-2.0.2-cp38-cp38-win_amd64.whl (192 kB)
# Using legacy setup.py install for ibm-db-sa, since package 'wheel' is not installed.
# Installing collected packages: ibm-db, typing-extensions, greenlet, sqlalchemy, ibm-db-sa
#   Attempting uninstall: ibm-db
#     Found existing installation: ibm-db 3.1.0
#     Uninstalling ibm-db-3.1.0:
#       Successfully uninstalled ibm-db-3.1.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.6.3
#     Uninstalling typing-extensions-4.6.3:
#       Successfully uninstalled typing-extensions-4.6.3
#   Attempting uninstall: greenlet
#     Found existing installation: greenlet 2.0.2
#     Uninstalling greenlet-2.0.2:
#       Successfully uninstalled greenlet-2.0.2
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Access is denied: 'C:\\Users\\KIIT\\AppData\\Local\\Programs\\Python\\Python38\\Lib\\site-packages\\~reenlet\\_greenlet.cp38-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
#
# WARNING: You are using pip version 20.1.1; however, version 23.2 is available.
# You should consider upgrading via the 'c:\users\kiit\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.
# Collecting sqlalchemy==1.3.24
# ERROR: ipython-sql 0.5.0 has requirement sqlalchemy>=2.0, but you'll have sqlalchemy 1.3.24 which is incompatible.
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Access is denied: 'C:\\Users\\KIIT\\AppData\\Local\\Programs\\Python\\Python38\\Lib\\site-packages\\~qlalchemy\\cyextension\\collections.cp38-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
#
# WARNING: You are using pip version 20.1.1; however, version 23.2 is available.
#   Using cached SQLAlchemy-1.3.24-cp38-cp38-win_amd64.whl (1.2 MB)
# Installing collected packages: sqlalchemy
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.16
#     Uninstalling SQLAlchemy-2.0.16:
#       Successfully uninstalled SQLAlchemy-2.0.16
# You should consider upgrading via the 'c:\users\kiit\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.
# Found existing installation: ipython-sql 0.5.0
# Uninstalling ipython-sql-0.5.0:
#   Successfully uninstalled ipython-sql-0.5.0
# Collecting ipython-sql==0.4.1
# WARNING: You are using pip version 20.1.1; however, version 23.2 is available.
# You should consider upgrading via the 'c:\users\kiit\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.
#   Downloading ipython_sql-0.4.1-py3-none-any.whl (21 kB)
# Collecting prettytable<1
#   Downloading prettytable-0.7.2.tar.bz2 (21 kB)
# Requirement already satisfied: sqlalchemy>=0.6.7 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from ipython-sql==0.4.1) (1.3.24)
# Requirement already satisfied: sqlparse in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from ipython-sql==0.4.1) (0.4.4)
# Requirement already satisfied: six in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from ipython-sql==0.4.1) (1.15.0)
# Requirement already satisfied: ipython-genutils>=0.1.0 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from ipython-sql==0.4.1) (0.2.0)
# Requirement already satisfied: ipython>=1.0 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from ipython-sql==0.4.1) (7.19.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (3.0.8)
# Requirement already satisfied: pygments in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (2.7.2)
# Requirement already satisfied: jedi>=0.10 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (0.17.2)
# Requirement already satisfied: setuptools>=18.5 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (47.1.0)
# Requirement already satisfied: pickleshare in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (5.9.0)
# Requirement already satisfied: decorator in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (4.4.2)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (0.4.4)
# Requirement already satisfied: backcall in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (0.2.0)
# Requirement already satisfied: wcwidth in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql==0.4.1) (0.2.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from jedi>=0.10->ipython>=1.0->ipython-sql==0.4.1) (0.7.1)
# Using legacy setup.py install for prettytable, since package 'wheel' is not installed.
# Installing collected packages: prettytable, ipython-sql
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 3.8.0
#     Uninstalling prettytable-3.8.0:
#       Successfully uninstalled prettytable-3.8.0
#     Running setup.py install for prettytable: started
#     Running setup.py install for prettytable: finished with status 'done'
# Successfully installed ipython-sql-0.4.1 prettytable-0.7.2

# %% [markdown]
# ### Connect to the database
#
# Let us first load the SQL extension and establish a connection with the database

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# **DB2 magic in case of  UI service credentials.**
#
#
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/images/servicecredentials.png" width="600">
#
# * Use the following format.
#
# * Add security=SSL at the end
#
# **%sql ibm_db_sa://my-username:my-password@my-hostname:my-port/my-db-name?security=SSL**

# %%
import csv, sqlite3

con = sqlite3.connect("SQLiteMagic.db")
cur = con.cursor()

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (1.3.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\kiit\appdata\local\programs\python\python38\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.1.1; however, version 23.2 is available.
# You should consider upgrading via the 'c:\Users\KIIT\AppData\Local\Programs\Python\Python38\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
df=pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv")
# %sql PERSIST df
# Out:
# Traceback (most recent call last):
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sql\magic.py", line 196, in execute
#     displaycon=self.displaycon,
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sql\connection.py", line 82, in set
#     "Environment variable $DATABASE_URL not set, and no connect string given."
# sql.connection.ConnectionError: Environment variable $DATABASE_URL not set, and no connect string given.
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# %sql ibm_db_sa://
# Out:
# Traceback (most recent call last):
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\engine\base.py", line 145, in __init__
#     return self.__branch_from._branch()
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\engine\base.py", line 3288, in raw_connection
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\pool\base.py", line 452, in connect
#     pool calls upon this :class:`._ConnectionRecord` to reconnect.
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\pool\base.py", line 1267, in _checkout
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\pool\base.py", line 716, in checkout
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\pool\impl.py", line 170, in _do_get
#     use_lifo=self._pool.use_lifo,
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\util\langhelpers.py", line 147, in __exit__
#     return %(target)s(%(fn)s, %(apply_kw)s)
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\pool\impl.py", line 167, in _do_get
#     pool_size=self._pool.maxsize,
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\pool\base.py", line 393, in _create_connection
#     raise NotImplementedError()
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\pool\base.py", line 678, in __init__
#     _refs.discard(connection_record)
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\pool\base.py", line 903, in __connect
#     util.warn(
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\util\langhelpers.py", line 147, in __exit__
#     return %(target)s(%(fn)s, %(apply_kw)s)
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\pool\base.py", line 898, in __connect
#     self.connection,
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\engine\create.py", line 637, in connect
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\engine\default.py", line 615, in connect
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\ibm_db_dbi.py", line 591, in connect
#     raise InterfaceError("connect expects a not None dsn value")
# ibm_db_dbi.InterfaceError: ibm_db_dbi::InterfaceError: connect expects a not None dsn value
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sql\magic.py", line 196, in execute
#     displaycon=self.displaycon,
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sql\connection.py", line 70, in set
#     else:
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sql\connection.py", line 55, in __init__
#     self.connections[repr(self.metadata.bind.url)] = self
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\engine\base.py", line 3264, in connect
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\engine\base.py", line 147, in __init__
#     return self.engine._connection_cls(
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\engine\base.py", line 2426, in _handle_dbapi_exception_noconnection
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\engine\base.py", line 145, in __init__
#     return self.__branch_from._branch()
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\engine\base.py", line 3288, in raw_connection
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\pool\base.py", line 452, in connect
#     pool calls upon this :class:`._ConnectionRecord` to reconnect.
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\pool\base.py", line 1267, in _checkout
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\pool\base.py", line 716, in checkout
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\pool\impl.py", line 170, in _do_get
#     use_lifo=self._pool.use_lifo,
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\util\langhelpers.py", line 147, in __exit__
#     return %(target)s(%(fn)s, %(apply_kw)s)
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\pool\impl.py", line 167, in _do_get
#     pool_size=self._pool.maxsize,
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\pool\base.py", line 393, in _create_connection
#     raise NotImplementedError()
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\pool\base.py", line 678, in __init__
#     _refs.discard(connection_record)
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\pool\base.py", line 903, in __connect
#     util.warn(
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\util\langhelpers.py", line 147, in __exit__
#     return %(target)s(%(fn)s, %(apply_kw)s)
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\pool\base.py", line 898, in __connect
#     self.connection,
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\engine\create.py", line 637, in connect
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sqlalchemy\engine\default.py", line 615, in connect
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\ibm_db_dbi.py", line 591, in connect
#     raise InterfaceError("connect expects a not None dsn value")
# sqlalchemy.exc.InterfaceError: (ibm_db_dbi.InterfaceError) ibm_db_dbi::InterfaceError: connect expects a not None dsn value
# (Background on this error at: https://sqlalche.me/e/20/rvf5)
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %% [markdown]
# ## Tasks
#
# Now write and execute SQL queries to solve the assignment tasks.
#
# ### Task 1
#
#
#
#
# ##### Display the names of the unique launch sites  in the space mission

# %%
df.head(2)
# Out:
#          Date Time (UTC) Booster_Version  Launch_Site  \
# 0  06/04/2010   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1  12/08/2010   15:43:00  F9 v1.0  B0004  CCAFS LC-40
#
#                                              Payload  PAYLOAD_MASS__KG_  \
# 0               Dragon Spacecraft Qualification Unit                0.0
# 1  Dragon demo flight C1, two CubeSats, barrel of...                0.0
#
#        Orbit         Customer Mission_Outcome      Landing_Outcome
# 0        LEO           SpaceX         Success  Failure (parachute)
# 1  LEO (ISS)  NASA (COTS) NRO         Success  Failure (parachute)

# %%
# %sql select * from df
# Out:
# Traceback (most recent call last):
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sql\magic.py", line 196, in execute
#     displaycon=self.displaycon,
#   File "c:\Users\KIIT\AppData\Local\Programs\Python\Python38\lib\site-packages\sql\connection.py", line 82, in set
#     "Environment variable $DATABASE_URL not set, and no connect string given."
# sql.connection.ConnectionError: Environment variable $DATABASE_URL not set, and no connect string given.
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %% [markdown]
# ### Task 2
#
#
# #####  Display 5 records where launch sites begin with the string 'CCA'

# %% [markdown]
# ### Task 3
#
#
#
#
# ##### Display the total payload mass carried by boosters launched by NASA (CRS)

# %% [markdown]
# ### Task 4
#
#
#
#
# ##### Display average payload mass carried by booster version F9 v1.1

# %% [markdown]
# ### Task 5
#
# ##### List the date when the first successful landing outcome in ground pad was acheived.
#
#
# _Hint:Use min function_

# %% [markdown]
# ### Task 6
#
# ##### List the names of the boosters which have success in drone ship and have payload mass greater than 4000 but less than 6000

# %% [markdown]
# ### Task 7
#
#
#
#
# ##### List the total number of successful and failure mission outcomes

# %% [markdown]
# ### Task 8
#
#
#
# ##### List the   names of the booster_versions which have carried the maximum payload mass. Use a subquery

# %% [markdown]
# ### Task 9
#
#
# ##### List the failed landing_outcomes in drone ship, their booster versions, and launch site names for in year 2015

# %% [markdown]
# ### Task 10
#
# ##### Rank the count of landing outcomes (such as Failure (drone ship) or Success (ground pad)) between the date 2010-06-04 and 2017-03-20, in descending order

# %% [markdown]
# ### Reference Links
#
# * <a href ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20String%20Patterns%20-%20Sorting%20-%20Grouping/instructional-labs.md.html?origin=www.coursera.org">Hands-on Lab : String Patterns, Sorting and Grouping</a>
#
# *  <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Built-in%20functions%20/Hands-on_Lab__Built-in_Functions.md.html?origin=www.coursera.org">Hands-on Lab: Built-in functions</a>
#
# *  <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Sub-queries%20and%20Nested%20SELECTs%20/instructional-labs.md.html?origin=www.coursera.org">Hands-on Lab : Sub-queries and Nested SELECT Statements</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-3-SQLmagic.ipynb">Hands-on Tutorial: Accessing Databases with SQL magic</a>
#
# *  <a href= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-4-Analyzing.ipynb">Hands-on Lab: Analyzing a real World Data Set</a>

# %% [markdown]
# ## Author(s)
#
# <h4> Lakshmi Holla </h4>

# %% [markdown]
# ## Other Contributors
#
# <h4> Rav Ahuja </h4>

# %% [markdown]
# ## Change log
# | Date | Version | Changed by | Change Description |
# |------|--------|--------|---------|
# | 2021-10-12 | 0.4 |Lakshmi Holla | Changed markdown|
# | 2021-08-24 | 0.3 |Lakshmi Holla | Added library update|
# | 2021-07-09 | 0.2 |Lakshmi Holla | Changes made in magic sql|
# | 2021-05-20 | 0.1 |Lakshmi Holla | Created Initial Version |

# %% [markdown]
# ## <h3 align="center"> © IBM Corporation 2021. All rights reserved. <h3/>
